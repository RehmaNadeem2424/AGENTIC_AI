# %% [markdown]
# <a href="https://colab.research.google.com/github/RehmaNadeem2424/AGENTIC_AI/blob/main/Assignment_NO_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GEMINI_API_KEY = userdata.get('GOOGLE_API_KEY_1')

# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=GEMINI_API_KEY)

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import requests
from io import BytesIO
from PIL import Image
from IPython.display import display

url = "https://cdn.pixabay.com/photo/2021/08/25/20/42/field-6574455_640.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426>

# %%
prompt = "explain this url in detail"

# %%
response = model.generate_content([img,prompt])
print(response.text)
# Out:
# That's a beautiful image!  Here's a description of the URL's contents:
#
# The image depicts a serene rural landscape at sunrise or sunset. The dominant feature is a large, solitary oak tree standing in a field of tall, golden-brown grass or grain.
#
#
# Here's a breakdown of the scene's elements:
#
# * **Sky:** The sky is the most striking element, filled with vibrant, pastel colors. Pink and purplish hues dominate, particularly concentrated in a band across the middle of the sky, suggesting the time of day is near sunrise or sunset.  There are also wispy, lighter clouds that add depth and texture to the sky.
#
# * **Tree:** A mature, full oak tree is centrally positioned. Its silhouette stands out against the colorful sky and the hazy field.  The tree is well-formed, suggesting age and strength.
#
# ...
